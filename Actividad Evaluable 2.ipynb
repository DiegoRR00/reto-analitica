# %% [markdown]
# # Actividad Evaluable 2: Obtención de estadísticas descriptivas
#
# **Diego Reyna Reyes A01657387**
# 1. Carga los datos usando tu lector de csv o con pandas. Es recomendable hacerlo con pandas.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
data = pd.read_csv("avocado.csv")
#data = data.sort_values(by = "Unnamed: 0",ascending= False)
data.head(10)
# Out:
#    Unnamed: 0        Date  AveragePrice  Total Volume     4046       4225  \
# 0           0  2015-12-27          1.33      64236.62  1036.74   54454.85
# 1           1  2015-12-20          1.35      54876.98   674.28   44638.81
# 2           2  2015-12-13          0.93     118220.22   794.70  109149.67
# 3           3  2015-12-06          1.08      78992.15  1132.00   71976.41
# 4           4  2015-11-29          1.28      51039.60   941.48   43838.39
# 5           5  2015-11-22          1.26      55979.78  1184.27   48067.99
# 6           6  2015-11-15          0.99      83453.76  1368.92   73672.72
# 7           7  2015-11-08          0.98     109428.33   703.75  101815.36
# 8           8  2015-11-01          1.02      99811.42  1022.15   87315.57
# 9           9  2015-10-25          1.07      74338.76   842.40   64757.44
#
#      4770  Total Bags  Small Bags  Large Bags  XLarge Bags          type  \
# 0   48.16     8696.87     8603.62       93.25          0.0  conventional
# ...

# %%
data.describe().transpose()
# Out:
#                 count           mean           std      min       25%  \
# Unnamed: 0    18249.0      24.232232  1.548104e+01     0.00     10.00
# AveragePrice  18249.0       1.405978  4.026766e-01     0.44      1.10
# Total Volume  18249.0  850644.013009  3.453545e+06    84.56  10838.58
# 4046          18249.0  293008.424531  1.264989e+06     0.00    854.07
# 4225          18249.0  295154.568356  1.204120e+06     0.00   3008.78
# 4770          18249.0   22839.735993  1.074641e+05     0.00      0.00
# Total Bags    18249.0  239639.202060  9.862424e+05     0.00   5088.64
# Small Bags    18249.0  182194.686696  7.461785e+05     0.00   2849.42
# Large Bags    18249.0   54338.088145  2.439660e+05     0.00    127.47
# XLarge Bags   18249.0    3106.426507  1.769289e+04     0.00      0.00
# year          18249.0    2016.147899  9.399385e-01  2015.00   2015.00
#
#                     50%        75%          max
# Unnamed: 0        24.00      38.00        52.00
# ...

# %% [markdown]
# 2. Verifica la cantidad de datos que tienes, las variables que contiene cada vector de datos e identifica el tipo de variables.

# %%
n = len(data)
print("Number of data: {}".format(n))
data.dtypes
# Out:
# Number of data: 18249
# Unnamed: 0        int64
# Date             object
# AveragePrice    float64
# Total Volume    float64
# 4046            float64
# 4225            float64
# 4770            float64
# Total Bags      float64
# Small Bags      float64
# Large Bags      float64
# XLarge Bags     float64
# type             object
# year              int64
# region           object
# dtype: object

# %% [markdown]
# Se encontró el número de datos mostrado arriba, los tipos de datos por columna, y se identificó que cada file incluye los datos de una compra-venta de aguacates.

# %% [markdown]
# 3. Analiza las variables para saber qué representa cada una y en qué rangos se encuentran. Si la descripción del problema no te lo indica, utiliza el máximo y el mínimo para encontrarlo.

# %%
#data = data.groupby("type")
data.head(60)
# Out:
#     Unnamed: 0        Date  AveragePrice  Total Volume       4046       4225  \
# 0            0  2015-12-27          1.33      64236.62    1036.74   54454.85
# 1            1  2015-12-20          1.35      54876.98     674.28   44638.81
# 2            2  2015-12-13          0.93     118220.22     794.70  109149.67
# 3            3  2015-12-06          1.08      78992.15    1132.00   71976.41
# 4            4  2015-11-29          1.28      51039.60     941.48   43838.39
# 5            5  2015-11-22          1.26      55979.78    1184.27   48067.99
# 6            6  2015-11-15          0.99      83453.76    1368.92   73672.72
# 7            7  2015-11-08          0.98     109428.33     703.75  101815.36
# 8            8  2015-11-01          1.02      99811.42    1022.15   87315.57
# 9            9  2015-10-25          1.07      74338.76     842.40   64757.44
# 10          10  2015-10-18          1.12      84843.44     924.86   75595.85
# ...

# %% [markdown]
# Para encontrar el valor de unnamed: 0, se analiza el valor de esta con la fecha y la región.
# Se denota que cada región cuenta con 52 filas, cada una con una región diferente. Para todas las regiones, el valor de Unnamed: 0 coincide con la fecha, y, al ver que la última semana del año coincide con el valor 0, y la primera semana del año coincide con el valor 51, se asume que es es el número de semanas restantes para el final del año.

# %%
plt.rcParams['figure.figsize'] = [10, 15]
data.hist()
# Out:
# array([[<Axes: title={'center': 'Unnamed: 0'}>,
#         <Axes: title={'center': 'AveragePrice'}>,
#         <Axes: title={'center': 'Total Volume'}>],
#        [<Axes: title={'center': '4046'}>,
#         <Axes: title={'center': '4225'}>,
#         <Axes: title={'center': '4770'}>],
#        [<Axes: title={'center': 'Total Bags'}>,
#         <Axes: title={'center': 'Small Bags'}>,
#         <Axes: title={'center': 'Large Bags'}>],
#        [<Axes: title={'center': 'XLarge Bags'}>,
#         <Axes: title={'center': 'year'}>, <Axes: >]], dtype=object)

# %%
corr = data.corr()
#cmp = corr[cols].loc[cols]
#Plot the correlation matrix
sns.set(font_scale=1.3)
sns.heatmap(corr, cbar=True, annot=True, square=True, fmt='.2f', annot_kws={'size': 10}, cmap = "Spectral_r")
k = 10
# Out:
# C:\Users\diego\AppData\Local\Temp\ipykernel_9124\3392544060.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   corr = data.corr()

# %%
sns.relplot(
    data=data,
    x="4046", y="Total Bags", hue = "Total Volume"
)
sns.relplot(
    data=data,
    x="4225", y="Total Bags", hue = "Total Volume"
)
sns.relplot(
    data=data,
    x="4770", y="Total Bags", hue = "Total Volume"
)

# %% [markdown]
# Como se puede ver, hay un relación similar a linear entre Total Bags, Total Volume y las columnas 4770, 4225 y 4046, por lo que se asume que estas están relacionadas con la compra.
#
# Se puede interpretar que estas indican la ganancia que se tiene por cada tamaño de costal adquirido, ya que, al aumentar el número de costeles comprados, el precio por unidad disminuye, por lo que estas unidades aumentan.
#
# Se considera que la columna 4770 está relacionada con Small Bag, ya que al ser menor cantidad, el precio al mayoreo no ofrece mayor ventaja, mientras que 4225 corresponde a XLarge Bags y 4046 corresponde a Large Bags, ya que 4225 tiene un promedio mayor a 4046, por lo que representa una mayor ganancia

# %% [markdown]
# Basándose en la media, mediana y desviación estándar de cada variable, ¿Qué conclusiones puedes entregar de los datos?

# %%
data.describe().transpose()
# Out:
#                 count           mean           std      min       25%  \
# Unnamed: 0    18249.0      24.232232  1.548104e+01     0.00     10.00
# AveragePrice  18249.0       1.405978  4.026766e-01     0.44      1.10
# Total Volume  18249.0  850644.013009  3.453545e+06    84.56  10838.58
# 4046          18249.0  293008.424531  1.264989e+06     0.00    854.07
# 4225          18249.0  295154.568356  1.204120e+06     0.00   3008.78
# 4770          18249.0   22839.735993  1.074641e+05     0.00      0.00
# Total Bags    18249.0  239639.202060  9.862424e+05     0.00   5088.64
# Small Bags    18249.0  182194.686696  7.461785e+05     0.00   2849.42
# Large Bags    18249.0   54338.088145  2.439660e+05     0.00    127.47
# XLarge Bags   18249.0    3106.426507  1.769289e+04     0.00      0.00
# year          18249.0    2016.147899  9.399385e-01  2015.00   2015.00
#
#                     50%        75%          max
# Unnamed: 0        24.00      38.00        52.00
# ...

# %% [markdown]
# Se puede concluir que la compra del producto es dependiente a la estación y el tiempo del año, ya que se tiene una gran desviación estándar en el volumen y el total de costales comprados. Esta demanda puede ocasionar grandes fluctuaciones en el precio promedio, que se mantiene constante durante casi todo el tiempo mostrado, sin embargo, se muestra un máximo muy alto.
